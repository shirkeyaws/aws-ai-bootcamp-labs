# %%
import boto3
import IPython
from pprint import pprint

client = boto3.client('translate', region_name='us-east-1')
polly = boto3.client('polly', region_name='us-east-1')

# %%
event_name = 'Amazon Web Services Summit Singapore'
message = 'Hello everyone, welcome to the {}. We hope you enjoy the day!'.format(event_name)

result=client.translate_text(
    Text=message,
    SourceLanguageCode='en',
    TargetLanguageCode='de'
)
pprint(result)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '181',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Wed, 04 Apr 2018 07:37:39 GMT',
#                                       'x-amzn-requestid': '0cc6f176-37db-11e8-afed-a58685fd61f9'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0cc6f176-37db-11e8-afed-a58685fd61f9',
#                       'RetryAttempts': 0},
#  'SourceLanguageCode': 'en',
#  'TargetLanguageCode': 'de',
#  'TranslatedText': 'Hallo an alle, willkommen auf dem Amazon Web Services '
#                    'Summit in Singapur. Wir hoffen, Sie genießen den Tag!'}

# %%
response = polly.synthesize_speech(
    Text=result['TranslatedText'],
    TextType="text",
    OutputFormat="mp3",                                           
    VoiceId="Hans")

pprint (response)


outfile = "pollyresponse_de.mp3"
data = response['AudioStream'].read()

with open(outfile,'wb') as f:
     f.write(data)
IPython.display.Audio(outfile)
# Out:
# {'AudioStream': <botocore.response.StreamingBody object at 0x10d1cb908>,
#  'ContentType': 'audio/mpeg',
#  'RequestCharacters': '107',
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-type': 'audio/mpeg',
#                                       'date': 'Wed, 04 Apr 2018 07:38:02 GMT',
#                                       'transfer-encoding': 'chunked',
#                                       'x-amzn-requestcharacters': '107',
#                                       'x-amzn-requestid': '1b84e631-37db-11e8-bf26-97bdc58c1bc6'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '1b84e631-37db-11e8-bf26-97bdc58c1bc6',
#                       'RetryAttempts': 0}}
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
# ...

# %%
result=client.translate_text(
    Text=result['TranslatedText'],
    SourceLanguageCode='de',
    TargetLanguageCode='en'
)
pprint(result)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '171',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Wed, 04 Apr 2018 07:38:43 GMT',
#                                       'x-amzn-requestid': '3388d19d-37db-11e8-912a-6f304b69f237'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '3388d19d-37db-11e8-912a-6f304b69f237',
#                       'RetryAttempts': 0},
#  'SourceLanguageCode': 'de',
#  'TargetLanguageCode': 'en',
#  'TranslatedText': 'Hello everyone, welcome to the Amazon Web Services Summit '
#                    'in Singapore. We hope you enjoy the day!'}

# %%
response = polly.synthesize_speech(
    Text=result['TranslatedText'],
    TextType="text",
    OutputFormat="mp3",                                           
    VoiceId="Joanna")

pprint (response)

# !rm ./pollyresponse_en.mp3
outfile = "pollyresponse_en.mp3"
data = response['AudioStream'].read()

with open(outfile,'wb') as f:
     f.write(data)
IPython.display.Audio(outfile)
# Out:
# {'AudioStream': <botocore.response.StreamingBody object at 0x10d1cb518>,
#  'ContentType': 'audio/mpeg',
#  'RequestCharacters': '98',
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-type': 'audio/mpeg',
#                                       'date': 'Wed, 04 Apr 2018 07:38:51 GMT',
#                                       'transfer-encoding': 'chunked',
#                                       'x-amzn-requestcharacters': '98',
#                                       'x-amzn-requestid': '383d0aa4-37db-11e8-a6eb-c9efefd832a1'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '383d0aa4-37db-11e8-a6eb-c9efefd832a1',
#                       'RetryAttempts': 0}}
# rm: ./pollyresponse_en.mp3: No such file or directory
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
# ...

# %%
response = polly.synthesize_speech(
    Text=result['TranslatedText'],
    TextType="text",
    OutputFormat="mp3",                                           
    VoiceId="Hans")

pprint (response)


outfile = "pollyresponse_en.mp3"
data = response['AudioStream'].read()

with open(outfile,'wb') as f:
     f.write(data)
IPython.display.Audio(outfile)
